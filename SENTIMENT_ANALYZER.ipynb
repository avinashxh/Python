# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashxh/Python/blob/master/SENTIMENT_ANALYZER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path = "/content/drive/MyDrive/Colab Notebooks/RESPONSES FINAL.csv"
df=pd.read_csv(path)
df.head(9)
# Out:
#              Timestamp                          Email address  \
# 0  01/05/2023 13:23:17               pranabnahak987@gmail.com
# 1  01/05/2023 13:26:20     21cseaiml026.mousuminayak@giet.edu
# 2  01/05/2023 13:29:08                 ramanpatra17@gmail.com
# 3  01/05/2023 13:30:10                     lipsam43@gmail.com
# 4  01/05/2023 13:37:30  21cse202.devarasettisreehita@giet.edu
# 5  01/05/2023 13:41:41               sritenduraja12@gmail.com
# 6  01/05/2023 13:51:36     21cseaiml036.saswatibaral@giet.edu
# 7  01/05/2023 14:13:35            sameekshyananda30@gmail.com
# 8  01/05/2023 15:15:17              avinashsahoo424@gmail.com
#
#                    Name         Roll no.  \
# 0    Pranab Kumar Nahak     21cseaiml038
# 1         Mousumi Nayak     21CSEAIML026
# 2            RamanPatra   21CSEAIMIL069
# 3         Lipsa Mahanta       21cseds013
# 4  Devarasetti sreehita         21cse202
# 5  SRITENDU KUMAR GHOSE         21CSE465
# 6         Saswati Baral     21CSEAIML036
# ...

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 16.7 MB/s eta 0:00:00

# %%
from transformers import pipeline

# %%
senti_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
senti_pipeline("im happy that you are here")
# Out:
# [{'label': 'POSITIVE', 'score': 0.999862551689148}]

# %%
senti_pipeline("hi,im fine but these days i was thinking of suicide")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9981684684753418}]

# %%
senti_pipeline("my sleep cycle is good")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9992350339889526}]

# %%
senti_pipeline("it was a hectic day")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9866032600402832}]

# %%
senti_pipeline("life in giet is very miserable")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9990191459655762}]

# %%
senti_pipeline("shradha is a good girl")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998589754104614}]

# %%
selected_row = 3
column1 = 'Hows your study life going ?'
column2 = 'Hows your life recently ?'
concatenated_column = df[column1] + ' ' + df[column2]
print(concatenated_column)
cell_value = concatenated_column[selected_row]
print(cell_value)
b = senti_pipeline(cell_value)
print(b)
# Out:
# 0                                            Good Good
# 1    It's good with consistency  It's going on with...
# 2               Moderate  Not soo good nether so bad.
# 3    Ok hai Aweosme. Currently enjoying my life, ch...
# 4    Good! Striving for better improvement everyday...
# 5    Moderate(not Bad not Good) Till now everything...
# 6                                   Good  Much better
# 7                                       poor messed up
# 8                   Study life is not going good Good
# dtype: object
# Ok hai Aweosme. Currently enjoying my life, cherishing each and every moment.
# [{'label': 'POSITIVE', 'score': 0.9997929930686951}]

# %%
selected_rows = [1, 2, 3, 4, 5, 6, 7, 8]
column1 = 'Hows your study life going ?'
column2 = 'Hows your life recently ?'
column3 = 'Are you going happy or unhappy these days ?'

for row in selected_rows:
    concatenated_column = df[column1][row] + ' --- ' + df[column2][row] + ' --- ' +df[column3][row]
    print(concatenated_column)
    b = senti_pipeline(concatenated_column)
    print(f"Row {row}: {b}")
# Out:
# It's good with consistency  --- It's going on with a pace --- Happy
# Row 1: [{'label': 'POSITIVE', 'score': 0.9998804330825806}]
# Moderate  --- Not soo good nether so bad.  --- Happy
# Row 2: [{'label': 'NEGATIVE', 'score': 0.9159259796142578}]
# Ok hai --- Aweosme. Currently enjoying my life, cherishing each and every moment. --- Nope..these days I am the happiest 😁
# Row 3: [{'label': 'POSITIVE', 'score': 0.9985470175743103}]
# Good! Striving for better improvement everyday  --- Its been good as my progress is satisfying  --- Balanced😊
# Row 4: [{'label': 'POSITIVE', 'score': 0.9996121525764465}]
# Moderate(not Bad not Good) --- Till now everything is running Good ,after that I don't know what is going to happen. --- Always Happy
# Row 5: [{'label': 'POSITIVE', 'score': 0.9991556406021118}]
# Good  --- Much better  --- Happy
# Row 6: [{'label': 'POSITIVE', 'score': 0.9998670816421509}]
# poor --- messed up --- unhappy
# Row 7: [{'label': 'NEGATIVE', 'score': 0.9998031258583069}]
# ...

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Email address', 'Name ', 'Roll no.',
#        'Which year are you currently studying ?', 'Mobile no.',
#        'Are you feeling bad about yourself that you are getting failure ?',
#        'Are you going happy or unhappy these days ?',
#        'When you get irritated , you start shouting on other peoples ?',
#        'Hows your study life going ?', 'Do you like being socially active ?',
#        'Hows your life recently ?', 'Share anything  you want . '],
#       dtype='object')

# %%
row_label = 6
column_name = 'Hows your study life going ?'
cell_value = df.loc[row_label, column_name]
print(cell_value)
c = senti_pipeline(cell_value)
print(c)
# Out:
# Good
# [{'label': 'POSITIVE', 'score': 0.9998161196708679}]
